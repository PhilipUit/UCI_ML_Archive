# %% [markdown]
# #### dataset info : http://archive.ics.uci.edu/ml/datasets/Bank+Marketing#
# #### http://dx.doi.org/10.1016/j.dss.2014.03.001
# #### http://www3.dsi.uminho.pt/pcortez/bib/2014-dss.txt
#
# Note: we are using the file that is 10% of the original dataset

# %% [markdown]
# ## lab info:
#
# "This assignment uses data(do see attachment) from the Bank Marketing data set from the UCI ML Archive (http://archive.ics.uci.edu/ml/datasets/Bank+Marketing).
#
# The data set has 20 feature columns plus one result column and we need to do some work to get it ready for further processing.
#
# 1. Reference the bank-additional-names.txt file for column types and what the names mean.
#
# 2. Make the following changes:
#
# Change column names to remove abbreviations, capitalize, add spaces, and generally make the names more "meaningful" to casual readers.
# Change column types to match the associated feature types.
# Replace word separators in strings like "-" or "." with spaces.
# Do any values need to be replaced with NaN or are they better the way they are?
# #8 in the text file states,
# 3. Missing Attribute Values: There are several missing values in some categorical attributes, all coded with the "unknown" label. These missing values can be treated as a possible class label or using deletion or imputation techniques.
#
# Decide what to do with these "unknown" values and defend your decision.
# Deliverable: Upload your notebook."

# %% [markdown]
# ## 1 -- setup
# ### load dataset & seperate into columns

# %%
# Here are packages we will import and will use throughout the lab(mostly). We will discuss them more while they are in use.

import os
import requests

import pandas as pd
import numpy as np


import re

# %%
## we must seperate this dataset into individual columns originally seperated by ';'
df = pd.read_csv('bank-additional.csv', sep=';')

# %%
# we see we havwe nice and clean dataset now
df.head
# Out:
# <bound method NDFrame.head of       age          job  marital          education default  housing     loan  \
# 0      30  blue-collar  married           basic.9y      no      yes       no
# 1      39     services   single        high.school      no       no       no
# 2      25     services  married        high.school      no      yes       no
# 3      38     services  married           basic.9y      no  unknown  unknown
# 4      47       admin.  married  university.degree      no      yes       no
# ...   ...          ...      ...                ...     ...      ...      ...
# 4114   30       admin.  married           basic.6y      no      yes      yes
# 4115   39       admin.  married        high.school      no      yes       no
# 4116   27      student   single        high.school      no       no       no
# 4117   58       admin.  married        high.school      no       no       no
# 4118   34   management   single        high.school      no      yes       no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# 0      cellular   may         fri  ...         2    999         0
# 1     telephone   may         fri  ...         4    999         0
# 2     telephone   jun         wed  ...         1    999         0
# 3     telephone   jun         fri  ...         3    999         0
# 4      cellular   nov         mon  ...         1    999         0
# ...         ...   ...         ...  ...       ...    ...       ...
# 4114   cellular   jul         thu  ...         1    999         0
# 4115  telephone   jul         fri  ...         1    999         0
# 4116   cellular   may         mon  ...         2    999         1
# 4117   cellular   aug         fri  ...         1    999         0
# 4118   cellular   nov         wed  ...         1    999         0
#
#          poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0     nonexistent         -1.8          92.893          -46.2      1.313
# 1     nonexistent          1.1          93.994          -36.4      4.855
# 2     nonexistent          1.4          94.465          -41.8      4.962
# 3     nonexistent          1.4          94.465          -41.8      4.959
# 4     nonexistent         -0.1          93.200          -42.0      4.191
# ...           ...          ...             ...            ...        ...
# 4114  nonexistent          1.4          93.918          -42.7      4.958
# 4115  nonexistent          1.4          93.918          -42.7      4.959
# 4116      failure         -1.8          92.893          -46.2      1.354
# 4117  nonexistent          1.4          93.444          -36.1      4.966
# 4118  nonexistent         -0.1          93.200          -42.0      4.120
#
#       nr.employed   y
# 0          5099.1  no
# 1          5191.0  no
# 2          5228.1  no
# 3          5228.1  no
# 4          5195.8  no
# ...           ...  ..
# 4114       5228.1  no
# 4115       5228.1  no
# 4116       5099.1  no
# 4117       5228.1  no
# 4118       5195.8  no
#
# [4119 rows x 21 columns]>

# %% [markdown]
# ## 2 -- making changes
# #### checking shape and type

# %%
# checking type
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# checking shape. we see we have 21 columns now and 4,119 rows of data
print(df.shape)
# Out:
# (4119, 21)

# %%
# we see some unknown and nonexistent data. we will adjust this later on
x = df.iloc[:,2:].values
x[:5,:]
# Out:
# array([['married', 'basic.9y', 'no', 'yes', 'no', 'cellular', 'may',
#         'fri', 487, 2, 999, 0, 'nonexistent', -1.8, 92.89299999999999,
#         -46.2, 1.3130000000000002, 5099.1, 'no'],
#        ['single', 'high.school', 'no', 'no', 'no', 'telephone', 'may',
#         'fri', 346, 4, 999, 0, 'nonexistent', 1.1, 93.994, -36.4, 4.855,
#         5191.0, 'no'],
#        ['married', 'high.school', 'no', 'yes', 'no', 'telephone', 'jun',
#         'wed', 227, 1, 999, 0, 'nonexistent', 1.4, 94.465, -41.8, 4.962,
#         5228.1, 'no'],
#        ['married', 'basic.9y', 'no', 'unknown', 'unknown', 'telephone',
#         'jun', 'fri', 17, 3, 999, 0, 'nonexistent', 1.4, 94.465, -41.8,
#         4.959, 5228.1, 'no'],
#        ['married', 'university.degree', 'no', 'yes', 'no', 'cellular',
#         'nov', 'mon', 58, 1, 999, 0, 'nonexistent', -0.1, 93.2, -42.0,
#         4.191, 5195.8, 'no']], dtype=object)

# %% [markdown]
# #### aggregate mean average

# %%
#here is a simple way to see variables with intergers. We know that the mean of pdays is skewed due to all the '999' values. we will adjust this later
df.agg("mean")
# Out:
# age                 40.113620
# duration           256.788055
# campaign             2.537266
# pdays              960.422190
# previous             0.190337
# emp.var.rate         0.084972
# cons.price.idx      93.579704
# cons.conf.idx      -40.499102
# euribor3m            3.621356
# nr.employed       5166.481695
# dtype: float64

# %% [markdown]
# #### Transpose

# %%
## to get a better perspective of the dataset
df.T
# we can see pdays has many '999' values,  poutcome has nonexixtent/failures, and there could be other unknown data we might need to sort out
# Out:
#                        0            1            2            3     \
# age                      30           39           25           38
# job             blue-collar     services     services     services
# marital             married       single      married      married
# education          basic.9y  high.school  high.school     basic.9y
# default                  no           no           no           no
# housing                 yes           no          yes      unknown
# loan                     no           no           no      unknown
# contact            cellular    telephone    telephone    telephone
# month                   may          may          jun          jun
# day_of_week             fri          fri          wed          fri
# duration                487          346          227           17
# campaign                  2            4            1            3
# pdays                   999          999          999          999
# previous                  0            0            0            0
# poutcome        nonexistent  nonexistent  nonexistent  nonexistent
# emp.var.rate           -1.8          1.1          1.4          1.4
# cons.price.idx       92.893       93.994       94.465       94.465
# cons.conf.idx         -46.2        -36.4        -41.8        -41.8
# euribor3m             1.313        4.855        4.962        4.959
# nr.employed          5099.1         5191       5228.1       5228.1
# y                        no           no           no           no
#
#                              4                  5                  6     \
# age                            47                 32                 32
# job                        admin.           services             admin.
# marital                   married             single             single
# education       university.degree  university.degree  university.degree
# default                        no                 no                 no
# housing                       yes                 no                yes
# loan                           no                 no                 no
# contact                  cellular           cellular           cellular
# month                         nov                sep                sep
# day_of_week                   mon                thu                mon
# duration                       58                128                290
# campaign                        1                  3                  4
# pdays                         999                999                999
# previous                        0                  2                  0
# poutcome              nonexistent            failure        nonexistent
# emp.var.rate                 -0.1               -1.1               -1.1
# cons.price.idx               93.2             94.199             94.199
# cons.conf.idx                 -42              -37.5              -37.5
# euribor3m                   4.191              0.884              0.879
# nr.employed                5195.8             4963.6             4963.6
# y                              no                 no                 no
#
#                              7                    8            9     ...  \
# age                            41                   31           35  ...
# job                  entrepreneur             services  blue-collar  ...
# marital                   married             divorced      married  ...
# education       university.degree  professional.course     basic.9y  ...
# default                   unknown                   no      unknown  ...
# housing                       yes                   no           no  ...
# loan                           no                   no           no  ...
# contact                  cellular             cellular    telephone  ...
# month                         nov                  nov          may  ...
# day_of_week                   mon                  tue          thu  ...
# duration                       44                   68          170  ...
# campaign                        2                    1            1  ...
# pdays                         999                  999          999  ...
# previous                        0                    1            0  ...
# poutcome              nonexistent              failure  nonexistent  ...
# emp.var.rate                 -0.1                 -0.1          1.1  ...
# cons.price.idx               93.2                 93.2       93.994  ...
# cons.conf.idx                 -42                  -42        -36.4  ...
# euribor3m                   4.191                4.153        4.855  ...
# nr.employed                5195.8               5195.8         5191  ...
# y                              no                   no           no  ...
#
#                        4109         4110               4111  \
# age                      63           53                 30
# job                 retired    housemaid         technician
# marital             married     divorced            married
# education       high.school     basic.6y  university.degree
# default                  no      unknown                 no
# housing                  no      unknown                 no
# loan                     no      unknown                yes
# contact            cellular    telephone           cellular
# month                   oct          may                jun
# day_of_week             wed          fri                fri
# duration               1386           85                131
# campaign                  1            2                  1
# pdays                   999          999                999
# previous                  0            0                  1
# poutcome        nonexistent  nonexistent            failure
# emp.var.rate           -3.4          1.1               -1.7
# cons.price.idx       92.431       93.994             94.055
# cons.conf.idx         -26.9        -36.4              -39.8
# euribor3m              0.74        4.855              0.748
# nr.employed          5017.5         5191             4991.6
# y                        no           no                 no
#
#                                4112               4113         4114  \
# age                              31                 31           30
# job                      technician             admin.       admin.
# marital                      single             single      married
# education       professional.course  university.degree     basic.6y
# default                          no                 no           no
# housing                         yes                yes          yes
# loan                             no                 no          yes
# contact                    cellular           cellular     cellular
# month                           nov                nov          jul
# day_of_week                     thu                thu          thu
# duration                        155                463           53
# campaign                          1                  1            1
# pdays                           999                999          999
# previous                          0                  0            0
# poutcome                nonexistent        nonexistent  nonexistent
# emp.var.rate                   -0.1               -0.1          1.4
# cons.price.idx                 93.2               93.2       93.918
# cons.conf.idx                   -42                -42        -42.7
# euribor3m                     4.076              4.076        4.958
# nr.employed                  5195.8             5195.8       5228.1
# y                                no                 no           no
#
#                        4115         4116         4117         4118
# age                      39           27           58           34
# job                  admin.      student       admin.   management
# marital             married       single      married       single
# education       high.school  high.school  high.school  high.school
# default                  no           no           no           no
# housing                 yes           no           no          yes
# loan                     no           no           no           no
# contact           telephone     cellular     cellular     cellular
# month                   jul          may          aug          nov
# day_of_week             fri          mon          fri          wed
# duration                219           64          528          175
# campaign                  1            2            1            1
# pdays                   999          999          999          999
# previous                  0            1            0            0
# poutcome        nonexistent      failure  nonexistent  nonexistent
# emp.var.rate            1.4         -1.8          1.4         -0.1
# cons.price.idx       93.918       92.893       93.444         93.2
# cons.conf.idx         -42.7        -46.2        -36.1          -42
# euribor3m             4.959        1.354        4.966         4.12
# nr.employed          5228.1       5099.1       5228.1       5195.8
# y                        no           no           no           no
#
# [21 rows x 4119 columns]

# %% [markdown]
# #### stack by 'job'

# %%
# an interesting perspective by job type
st = df.pivot_table(index='job').stack
st
# we are mostly just testing the water right now to get differnt perspective
# Out:
# <bound method DataFrame.stack of                      age  campaign  cons.conf.idx  cons.price.idx    duration  \
# job
# admin.         38.240119  2.642292     -40.014723       93.527008  261.871542
# blue-collar    39.265837  2.432127     -41.571493       93.669430  261.852941
# entrepreneur   42.202703  2.216216     -40.839865       93.614682  249.202703
# housemaid      45.672727  2.463636     -39.324545       93.658536  229.663636
# management     42.429012  2.432099     -40.591667       93.483056  246.799383
# retired        60.873494  2.397590     -39.034337       93.487506  311.789157
# self-employed  40.679245  2.817610     -40.323899       93.575283  254.924528
# services       38.513995  2.844784     -41.532061       93.626059  232.529262
# student        26.695122  1.951220     -39.665854       93.448329  287.134146
# technician     38.622287  2.509407     -39.895948       93.575912  253.286541
# unemployed     39.531532  2.621622     -40.505405       93.568532  249.801802
# unknown        46.846154  2.333333     -38.971795       93.679744  234.410256
#
#                emp.var.rate  euribor3m  nr.employed       pdays  previous
# job
# admin.             0.061462   3.601909  5165.542885  944.025692  0.192688
# blue-collar        0.235520   3.742370  5174.265611  983.270362  0.147059
# entrepreneur       0.263514   3.931493  5180.600000  992.263514  0.141892
# housemaid          0.426364   4.009182  5179.862727  980.909091  0.100000
# management        -0.049691   3.553451  5165.971914  953.015432  0.246914
# retired           -0.580120   2.875741  5126.062048  897.301205  0.325301
# self-employed      0.086164   3.669296  5166.974843  967.691824  0.207547
# services           0.067684   3.552776  5165.806870  978.773537  0.178117
# student           -1.192683   2.165354  5092.046341  902.426829  0.487805
# technician         0.248770   3.800760  5173.511433  964.548480  0.169320
# unemployed        -0.181982   3.373216  5153.002703  927.369369  0.234234
# unknown            0.305128   3.934487  5174.471795  947.923077  0.179487  >

# %%
# loan
st = df.pivot_table(index='loan').stack
st
# Out:
# <bound method DataFrame.stack of                age  campaign  cons.conf.idx  cons.price.idx    duration  \
# loan
# no       40.163332  2.564049     -40.512213       93.582737  259.236787
# unknown  39.523810  2.580952     -40.207619       93.634800  243.923810
# yes      39.956391  2.395489     -40.479098       93.555732  246.487218
#
#          emp.var.rate  euribor3m  nr.employed       pdays  previous
# loan
# no           0.081188   3.612484  5165.858107  959.856972  0.190206
# unknown      0.228571   3.743962  5171.364762  961.190476  0.285714
# yes          0.081353   3.646675  5168.851128  963.147368  0.175940  >

# %%
# loan pivot_table
st = df.pivot_table(index='loan').stack
st
# Out:
# <bound method DataFrame.stack of                age  campaign  cons.conf.idx  cons.price.idx    duration  \
# loan
# no       40.163332  2.564049     -40.512213       93.582737  259.236787
# unknown  39.523810  2.580952     -40.207619       93.634800  243.923810
# yes      39.956391  2.395489     -40.479098       93.555732  246.487218
#
#          emp.var.rate  euribor3m  nr.employed       pdays  previous
# loan
# no           0.081188   3.612484  5165.858107  959.856972  0.190206
# unknown      0.228571   3.743962  5171.364762  961.190476  0.285714
# yes          0.081353   3.646675  5168.851128  963.147368  0.175940  >

# %% [markdown]
# ### rename
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rename.html

# %%
df.rename(columns={1: "Age"})
# Out:
#       age          job  marital          education default  housing     loan  \
# 0      30  blue-collar  married           basic.9y      no      yes       no
# 1      39     services   single        high.school      no       no       no
# 2      25     services  married        high.school      no      yes       no
# 3      38     services  married           basic.9y      no  unknown  unknown
# 4      47       admin.  married  university.degree      no      yes       no
# ...   ...          ...      ...                ...     ...      ...      ...
# 4114   30       admin.  married           basic.6y      no      yes      yes
# 4115   39       admin.  married        high.school      no      yes       no
# 4116   27      student   single        high.school      no       no       no
# 4117   58       admin.  married        high.school      no       no       no
# 4118   34   management   single        high.school      no      yes       no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# 0      cellular   may         fri  ...         2    999         0
# 1     telephone   may         fri  ...         4    999         0
# 2     telephone   jun         wed  ...         1    999         0
# 3     telephone   jun         fri  ...         3    999         0
# 4      cellular   nov         mon  ...         1    999         0
# ...         ...   ...         ...  ...       ...    ...       ...
# 4114   cellular   jul         thu  ...         1    999         0
# 4115  telephone   jul         fri  ...         1    999         0
# 4116   cellular   may         mon  ...         2    999         1
# 4117   cellular   aug         fri  ...         1    999         0
# 4118   cellular   nov         wed  ...         1    999         0
#
#          poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0     nonexistent         -1.8          92.893          -46.2      1.313
# 1     nonexistent          1.1          93.994          -36.4      4.855
# 2     nonexistent          1.4          94.465          -41.8      4.962
# 3     nonexistent          1.4          94.465          -41.8      4.959
# 4     nonexistent         -0.1          93.200          -42.0      4.191
# ...           ...          ...             ...            ...        ...
# 4114  nonexistent          1.4          93.918          -42.7      4.958
# 4115  nonexistent          1.4          93.918          -42.7      4.959
# 4116      failure         -1.8          92.893          -46.2      1.354
# 4117  nonexistent          1.4          93.444          -36.1      4.966
# 4118  nonexistent         -0.1          93.200          -42.0      4.120
#
#       nr.employed   y
# 0          5099.1  no
# 1          5191.0  no
# 2          5228.1  no
# 3          5228.1  no
# 4          5195.8  no
# ...           ...  ..
# 4114       5228.1  no
# 4115       5228.1  no
# 4116       5099.1  no
# 4117       5228.1  no
# 4118       5195.8  no
#
# [4119 rows x 21 columns]

# %%
df.T
# Out:
#                        0            1            2            3     \
# age                      30           39           25           38
# job             blue-collar     services     services     services
# marital             married       single      married      married
# education          basic.9y  high.school  high.school     basic.9y
# default                  no           no           no           no
# housing                 yes           no          yes      unknown
# loan                     no           no           no      unknown
# contact            cellular    telephone    telephone    telephone
# month                   may          may          jun          jun
# day_of_week             fri          fri          wed          fri
# duration                487          346          227           17
# campaign                  2            4            1            3
# pdays                   999          999          999          999
# previous                  0            0            0            0
# poutcome        nonexistent  nonexistent  nonexistent  nonexistent
# emp.var.rate           -1.8          1.1          1.4          1.4
# cons.price.idx       92.893       93.994       94.465       94.465
# cons.conf.idx         -46.2        -36.4        -41.8        -41.8
# euribor3m             1.313        4.855        4.962        4.959
# nr.employed          5099.1         5191       5228.1       5228.1
# y                        no           no           no           no
#
#                              4                  5                  6     \
# age                            47                 32                 32
# job                        admin.           services             admin.
# marital                   married             single             single
# education       university.degree  university.degree  university.degree
# default                        no                 no                 no
# housing                       yes                 no                yes
# loan                           no                 no                 no
# contact                  cellular           cellular           cellular
# month                         nov                sep                sep
# day_of_week                   mon                thu                mon
# duration                       58                128                290
# campaign                        1                  3                  4
# pdays                         999                999                999
# previous                        0                  2                  0
# poutcome              nonexistent            failure        nonexistent
# emp.var.rate                 -0.1               -1.1               -1.1
# cons.price.idx               93.2             94.199             94.199
# cons.conf.idx                 -42              -37.5              -37.5
# euribor3m                   4.191              0.884              0.879
# nr.employed                5195.8             4963.6             4963.6
# y                              no                 no                 no
#
#                              7                    8            9     ...  \
# age                            41                   31           35  ...
# job                  entrepreneur             services  blue-collar  ...
# marital                   married             divorced      married  ...
# education       university.degree  professional.course     basic.9y  ...
# default                   unknown                   no      unknown  ...
# housing                       yes                   no           no  ...
# loan                           no                   no           no  ...
# contact                  cellular             cellular    telephone  ...
# month                         nov                  nov          may  ...
# day_of_week                   mon                  tue          thu  ...
# duration                       44                   68          170  ...
# campaign                        2                    1            1  ...
# pdays                         999                  999          999  ...
# previous                        0                    1            0  ...
# poutcome              nonexistent              failure  nonexistent  ...
# emp.var.rate                 -0.1                 -0.1          1.1  ...
# cons.price.idx               93.2                 93.2       93.994  ...
# cons.conf.idx                 -42                  -42        -36.4  ...
# euribor3m                   4.191                4.153        4.855  ...
# nr.employed                5195.8               5195.8         5191  ...
# y                              no                   no           no  ...
#
#                        4109         4110               4111  \
# age                      63           53                 30
# job                 retired    housemaid         technician
# marital             married     divorced            married
# education       high.school     basic.6y  university.degree
# default                  no      unknown                 no
# housing                  no      unknown                 no
# loan                     no      unknown                yes
# contact            cellular    telephone           cellular
# month                   oct          may                jun
# day_of_week             wed          fri                fri
# duration               1386           85                131
# campaign                  1            2                  1
# pdays                   999          999                999
# previous                  0            0                  1
# poutcome        nonexistent  nonexistent            failure
# emp.var.rate           -3.4          1.1               -1.7
# cons.price.idx       92.431       93.994             94.055
# cons.conf.idx         -26.9        -36.4              -39.8
# euribor3m              0.74        4.855              0.748
# nr.employed          5017.5         5191             4991.6
# y                        no           no                 no
#
#                                4112               4113         4114  \
# age                              31                 31           30
# job                      technician             admin.       admin.
# marital                      single             single      married
# education       professional.course  university.degree     basic.6y
# default                          no                 no           no
# housing                         yes                yes          yes
# loan                             no                 no          yes
# contact                    cellular           cellular     cellular
# month                           nov                nov          jul
# day_of_week                     thu                thu          thu
# duration                        155                463           53
# campaign                          1                  1            1
# pdays                           999                999          999
# previous                          0                  0            0
# poutcome                nonexistent        nonexistent  nonexistent
# emp.var.rate                   -0.1               -0.1          1.4
# cons.price.idx                 93.2               93.2       93.918
# cons.conf.idx                   -42                -42        -42.7
# euribor3m                     4.076              4.076        4.958
# nr.employed                  5195.8             5195.8       5228.1
# y                                no                 no           no
#
#                        4115         4116         4117         4118
# age                      39           27           58           34
# job                  admin.      student       admin.   management
# marital             married       single      married       single
# education       high.school  high.school  high.school  high.school
# default                  no           no           no           no
# housing                 yes           no           no          yes
# loan                     no           no           no           no
# contact           telephone     cellular     cellular     cellular
# month                   jul          may          aug          nov
# day_of_week             fri          mon          fri          wed
# duration                219           64          528          175
# campaign                  1            2            1            1
# pdays                   999          999          999          999
# previous                  0            1            0            0
# poutcome        nonexistent      failure  nonexistent  nonexistent
# emp.var.rate            1.4         -1.8          1.4         -0.1
# cons.price.idx       93.918       92.893       93.444         93.2
# cons.conf.idx         -42.7        -46.2        -36.1          -42
# euribor3m             4.959        1.354        4.966         4.12
# nr.employed          5228.1       5099.1       5228.1       5195.8
# y                        no           no           no           no
#
# [21 rows x 4119 columns]

# %% [markdown]
# ### Change column Names using df.rename()

# %%
df.rename(columns={'age': "Age", 'job': 'Employment Status', 'marital': 'Marital', 'education': "Education", 'housing': "Housing", 'loan': "Loan", 'contact': "Contact", 'month': "Month", 'default': "Default", 'day_of_week': "Day", 'campaign': "Campaign"})
# Out:
#       Age Employment Status  Marital          Education Default  Housing  \
# 0      30       blue-collar  married           basic.9y      no      yes
# 1      39          services   single        high.school      no       no
# 2      25          services  married        high.school      no      yes
# 3      38          services  married           basic.9y      no  unknown
# 4      47            admin.  married  university.degree      no      yes
# ...   ...               ...      ...                ...     ...      ...
# 4114   30            admin.  married           basic.6y      no      yes
# 4115   39            admin.  married        high.school      no      yes
# 4116   27           student   single        high.school      no       no
# 4117   58            admin.  married        high.school      no       no
# 4118   34        management   single        high.school      no      yes
#
#          Loan    Contact Month  Day  ...  Campaign  pdays  previous  \
# 0          no   cellular   may  fri  ...         2    999         0
# 1          no  telephone   may  fri  ...         4    999         0
# 2          no  telephone   jun  wed  ...         1    999         0
# 3     unknown  telephone   jun  fri  ...         3    999         0
# 4          no   cellular   nov  mon  ...         1    999         0
# ...       ...        ...   ...  ...  ...       ...    ...       ...
# 4114      yes   cellular   jul  thu  ...         1    999         0
# 4115       no  telephone   jul  fri  ...         1    999         0
# 4116       no   cellular   may  mon  ...         2    999         1
# 4117       no   cellular   aug  fri  ...         1    999         0
# 4118       no   cellular   nov  wed  ...         1    999         0
#
#          poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0     nonexistent         -1.8          92.893          -46.2      1.313
# 1     nonexistent          1.1          93.994          -36.4      4.855
# 2     nonexistent          1.4          94.465          -41.8      4.962
# 3     nonexistent          1.4          94.465          -41.8      4.959
# 4     nonexistent         -0.1          93.200          -42.0      4.191
# ...           ...          ...             ...            ...        ...
# 4114  nonexistent          1.4          93.918          -42.7      4.958
# 4115  nonexistent          1.4          93.918          -42.7      4.959
# 4116      failure         -1.8          92.893          -46.2      1.354
# 4117  nonexistent          1.4          93.444          -36.1      4.966
# 4118  nonexistent         -0.1          93.200          -42.0      4.120
#
#       nr.employed   y
# 0          5099.1  no
# 1          5191.0  no
# 2          5228.1  no
# 3          5228.1  no
# 4          5195.8  no
# ...           ...  ..
# 4114       5228.1  no
# 4115       5228.1  no
# 4116       5099.1  no
# 4117       5228.1  no
# 4118       5195.8  no
#
# [4119 rows x 21 columns]

# %%
df.agg("mean")
# Out:
# age                 40.113620
# duration           256.788055
# campaign             2.537266
# pdays              960.422190
# previous             0.190337
# emp.var.rate         0.084972
# cons.price.idx      93.579704
# cons.conf.idx      -40.499102
# euribor3m            3.621356
# nr.employed       5166.481695
# dtype: float64

# %% [markdown]
# ## Renaming columns for types to match feature types

# %%
#this will make the names easier to understand and match better with the .txt file of descriptions
df1 = df.rename(columns={'age': "Age of client", 'job': 'Employment Status', 'marital': 'Marital Status', 'education': "Education", 'housing': "Housing", 'loan': "Loan", 'contact': "Contact", 'month': "Month", 'default': "Default", 'day_of_week': "Day", 'campaign': "Contracts performed during Campaign", 'pdays': "Days Since Clinet contact", 'previous': "Contracts previously performed before this contract", 'poutcome': "Prev. Marketing Outcome", 'emp.var.rate': "Quarterly Employment Variation rate", 'cons.price.idx': "Monthly Consumer Price Index", 'cons.conf.idx': "Monthly Consumer Confidence Index", 'euribor3m': "Euribor 3 Month Rate - daily", 'nr.employed': "Number of Employees - quarterly", 'y': "Term Deposit?", 'duration': "Duration in seconds of last conversation"})
df1
# Out:
#       Age of client Employment Status Marital Status          Education  \
# 0                30       blue-collar        married           basic.9y
# 1                39          services         single        high.school
# 2                25          services        married        high.school
# 3                38          services        married           basic.9y
# 4                47            admin.        married  university.degree
# ...             ...               ...            ...                ...
# 4114             30            admin.        married           basic.6y
# 4115             39            admin.        married        high.school
# 4116             27           student         single        high.school
# 4117             58            admin.        married        high.school
# 4118             34        management         single        high.school
#
#      Default  Housing     Loan    Contact Month  Day  ...  \
# 0         no      yes       no   cellular   may  fri  ...
# 1         no       no       no  telephone   may  fri  ...
# 2         no      yes       no  telephone   jun  wed  ...
# 3         no  unknown  unknown  telephone   jun  fri  ...
# 4         no      yes       no   cellular   nov  mon  ...
# ...      ...      ...      ...        ...   ...  ...  ...
# 4114      no      yes      yes   cellular   jul  thu  ...
# 4115      no      yes       no  telephone   jul  fri  ...
# 4116      no       no       no   cellular   may  mon  ...
# 4117      no       no       no   cellular   aug  fri  ...
# 4118      no      yes       no   cellular   nov  wed  ...
#
#       Contracts performed during Campaign  Days Since Clinet contact  \
# 0                                       2                        999
# 1                                       4                        999
# 2                                       1                        999
# 3                                       3                        999
# 4                                       1                        999
# ...                                   ...                        ...
# 4114                                    1                        999
# 4115                                    1                        999
# 4116                                    2                        999
# 4117                                    1                        999
# 4118                                    1                        999
#
#       Contracts previously performed before this contract  \
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 4114                                                  0
# 4115                                                  0
# 4116                                                  1
# 4117                                                  0
# 4118                                                  0
#
#       Prev. Marketing Outcome Quarterly Employment Variation rate  \
# 0                 nonexistent                                -1.8
# 1                 nonexistent                                 1.1
# 2                 nonexistent                                 1.4
# 3                 nonexistent                                 1.4
# 4                 nonexistent                                -0.1
# ...                       ...                                 ...
# 4114              nonexistent                                 1.4
# 4115              nonexistent                                 1.4
# 4116                  failure                                -1.8
# 4117              nonexistent                                 1.4
# 4118              nonexistent                                -0.1
#
#       Monthly Consumer Price Index  Monthly Consumer Confidence Index  \
# 0                           92.893                              -46.2
# 1                           93.994                              -36.4
# 2                           94.465                              -41.8
# 3                           94.465                              -41.8
# 4                           93.200                              -42.0
# ...                            ...                                ...
# 4114                        93.918                              -42.7
# 4115                        93.918                              -42.7
# 4116                        92.893                              -46.2
# 4117                        93.444                              -36.1
# 4118                        93.200                              -42.0
#
#       Euribor 3 Month Rate - daily  Number of Employees - quarterly  \
# 0                            1.313                           5099.1
# 1                            4.855                           5191.0
# 2                            4.962                           5228.1
# 3                            4.959                           5228.1
# 4                            4.191                           5195.8
# ...                            ...                              ...
# 4114                         4.958                           5228.1
# 4115                         4.959                           5228.1
# 4116                         1.354                           5099.1
# 4117                         4.966                           5228.1
# 4118                         4.120                           5195.8
#
#       Term Deposit?
# 0                no
# 1                no
# 2                no
# 3                no
# 4                no
# ...             ...
# 4114             no
# 4115             no
# 4116             no
# 4117             no
# 4118             no
#
# [4119 rows x 21 columns]

# %% [markdown]
# We see we successfully changed the names and types to make more sense. We now have some manipulation to continue with the dataset

# %%
#checking aggregations of means with new names that are easier to understand and more meaningful
df1.agg("mean")
#this is an easy way to identify any quantifiable/numeric variables
# Out:
# Age of client                                            40.113620
# Duration in seconds of last conversation                256.788055
# Contracts performed during Campaign                       2.537266
# Days Since Clinet contact                               960.422190
# Contracts previously performed before this contract       0.190337
# Quarterly Employment Variation rate                       0.084972
# Monthly Consumer Price Index                             93.579704
# Monthly Consumer Confidence Index                       -40.499102
# Euribor 3 Month Rate - daily                              3.621356
# Number of Employees - quarterly                        5166.481695
# dtype: float64

# %% [markdown]
# pivots by various non-interger variables to give unique insight:

# %%
#pivot by 'Marital Status' -- unique perspective
df1.pivot_table(columns={'Marital Status'})
# having unknown data could be helpful for further analysis, so we will leave
# Out:
# Marital Status                                         divorced      married  \
# Age of client                                         45.107623    42.389398
# Contracts performed during Campaign                    2.542601     2.527700
# Contracts previously performed before this cont...     0.174888     0.173774
# Days Since Clinet contact                            972.255605   964.162216
# Duration in seconds of last conversation             263.163677   256.289757
# Euribor 3 Month Rate - daily                           3.707177     3.728554
# Monthly Consumer Confidence Index                    -40.621973   -40.357114
# Monthly Consumer Price Index                          93.600547    93.599039
# Number of Employees - quarterly                     5170.145964  5170.724472
# Quarterly Employment Variation rate                    0.143274     0.172260
#
# Marital Status                                           single      unknown
# Age of client                                         33.209020    42.272727
# Contracts performed during Campaign                    2.555941     2.545455
# Contracts previously performed before this cont...     0.233304     0.090909
# Days Since Clinet contact                            947.338248   999.000000
# Duration in seconds of last conversation             254.647875   336.272727
# Euribor 3 Month Rate - daily                           3.352657     3.855182
# Monthly Consumer Confidence Index                    -40.768257   -39.690909
# Monthly Consumer Price Index                          93.529971    93.537545
# Number of Employees - quarterly                     5155.756114  5174.409091
# Quarterly Employment Variation rate                   -0.128448     0.181818

# %%
#pivot by 'Prev. Marketing Outcome'
df1.pivot_table(columns={'Prev. Marketing Outcome'})
#having 'nonexistent outcomes' still have data that could possibly be useful, so we will leave
# Out:
# Prev. Marketing Outcome                                 failure  nonexistent  \
# Age of client                                         40.400881    39.981266
# Contracts performed during Campaign                    1.958150     2.641783
# Contracts previously performed before this cont...     1.209251     0.000000
# Days Since Clinet contact                            959.825991   999.000000
# Duration in seconds of last conversation             254.612335   254.561169
# Euribor 3 Month Rate - daily                           1.652077     3.979500
# Monthly Consumer Confidence Index                    -42.633040   -40.309736
# Monthly Consumer Price Index                          93.101676    93.648752
# Number of Employees - quarterly                     5090.048238  5181.894039
# Quarterly Employment Variation rate                   -1.656167     0.394891
#
# Prev. Marketing Outcome                                 success
# Age of client                                         42.478873
# Contracts performed during Campaign                    1.795775
# Contracts previously performed before this cont...     1.654930
# Days Since Clinet contact                              5.218310
# Duration in seconds of last conversation             318.992958
# Euribor 3 Month Rate - daily                           1.031979
# Monthly Consumer Confidence Index                    -38.374648
# Monthly Consumer Price Index                          93.394979
# Number of Employees - quarterly                     5028.475352
# Quarterly Employment Variation rate                   -2.037324

# %%
#pivot table by month
df1.pivot_table(columns={'Month'})
# we see no data for 2 months: Jan & Feb
# Out:
# Month                                                       apr          aug  \
# Age of client                                         41.158140    41.405660
# Contracts performed during Campaign                    1.962791     2.705975
# Contracts previously performed before this cont...     0.372093     0.135220
# Days Since Clinet contact                            966.655814   955.224843
# Duration in seconds of last conversation             291.293023   218.435535
# Euribor 3 Month Rate - daily                           1.362698     4.270874
# Monthly Consumer Confidence Index                    -46.286047   -35.659906
# Monthly Consumer Price Index                          93.118888    93.327670
# Number of Employees - quarterly                     5093.213488  5197.916038
# Quarterly Employment Variation rate                   -1.800000     0.732075
#
# Month                                                       dec          jul  \
# Age of client                                         46.000000    39.008439
# Contracts performed during Campaign                    2.636364     3.085795
# Contracts previously performed before this cont...     0.681818     0.054852
# Days Since Clinet contact                            773.227273   982.282700
# Duration in seconds of last conversation             324.318182   278.015471
# Euribor 3 Month Rate - daily                           0.830318     4.710661
# Monthly Consumer Confidence Index                    -33.586364   -42.419550
# Monthly Consumer Price Index                          92.714955    93.902000
# Number of Employees - quarterly                     5030.445455  5215.130098
# Quarterly Employment Variation rate                   -2.872727     1.184529
#
# Month                                                       jun          mar  \
# Age of client                                         39.833962    41.895833
# Contracts performed during Campaign                    2.988679     1.958333
# Contracts previously performed before this cont...     0.084906     0.729167
# Days Since Clinet contact                            968.996226   772.125000
# Duration in seconds of last conversation             245.035849   274.916667
# Euribor 3 Month Rate - daily                           4.221585     1.179729
# Monthly Consumer Confidence Index                    -41.567925   -42.716667
# Monthly Consumer Price Index                          94.233887    93.095042
# Number of Employees - quarterly                     5195.895283  5055.783333
# Quarterly Employment Variation rate                    0.651132    -1.800000
#
# Month                                                       may          nov  \
# Age of client                                         39.420174    40.340807
# Contracts performed during Campaign                    2.423803     1.856502
# Contracts previously performed before this cont...     0.171988     0.302691
# Days Since Clinet contact                            981.682148   941.091928
# Duration in seconds of last conversation             259.260522   257.051570
# Euribor 3 Month Rate - daily                           3.245085     3.675067
# Monthly Consumer Confidence Index                    -40.705806   -41.513004
# Monthly Consumer Price Index                          93.515037    93.239848
# Number of Employees - quarterly                     5148.142816  5168.913004
# Quarterly Employment Variation rate                   -0.204790    -0.420179
#
# Month                                                       oct          sep
# Age of client                                         44.797101    43.296875
# Contracts performed during Campaign                    1.463768     1.703125
# Contracts previously performed before this cont...     0.637681     1.062500
# Days Since Clinet contact                            855.289855   673.140625
# Duration in seconds of last conversation             271.449275   275.812500
# Euribor 3 Month Rate - daily                           1.170957     0.842047
# Monthly Consumer Confidence Index                    -34.624638   -34.492188
# Monthly Consumer Price Index                          93.178855    93.488062
# Number of Employees - quarterly                     5017.381159  4984.654687
# Quarterly Employment Variation rate                   -2.446377    -1.998437

# %%
#pivot by Education Level
df1.pivot_table(columns={'Education'})
# we see unknown values in this output, but they contain data so we should leave it be
# Out:
# Education                                              basic.4y     basic.6y  \
# Age of client                                         47.657343    40.144737
# Contracts performed during Campaign                    2.421911     2.649123
# Contracts previously performed before this cont...     0.142191     0.140351
# Days Since Clinet contact                            973.524476   985.881579
# Duration in seconds of last conversation             255.682984   259.000000
# Euribor 3 Month Rate - daily                           3.828089     3.810469
# Monthly Consumer Confidence Index                    -40.465501   -41.539912
# Monthly Consumer Price Index                          93.666193    93.689114
# Number of Employees - quarterly                     5174.093939  5176.600000
# Quarterly Employment Variation rate                    0.291841     0.271053
#
# Education                                              basic.9y  high.school  \
# Age of client                                         39.231707    38.097720
# Contracts performed during Campaign                    2.348432     2.630836
# Contracts previously performed before this cont...     0.158537     0.206298
# Days Since Clinet contact                            979.963415   958.022801
# Duration in seconds of last conversation             250.538328   258.534202
# Euribor 3 Month Rate - daily                           3.722737     3.511732
# Monthly Consumer Confidence Index                    -41.443554   -40.995765
# Monthly Consumer Price Index                          93.640805    93.564314
# Number of Employees - quarterly                     5173.182578  5163.212595
# Quarterly Employment Variation rate                    0.183275    -0.002497
#
# Education                                           illiterate  \
# Age of client                                           42.000
# Contracts performed during Campaign                      4.000
# Contracts previously performed before this cont...       0.000
# Days Since Clinet contact                              999.000
# Duration in seconds of last conversation               146.000
# Euribor 3 Month Rate - daily                             0.834
# Monthly Consumer Confidence Index                      -31.400
# Monthly Consumer Price Index                            92.201
# Number of Employees - quarterly                       5076.200
# Quarterly Employment Variation rate                     -2.900
#
# Education                                           professional.course  \
# Age of client                                                 40.207477
# Contracts performed during Campaign                            2.512150
# Contracts previously performed before this cont...             0.194393
# Days Since Clinet contact                                    958.211215
# Duration in seconds of last conversation                     278.816822
# Euribor 3 Month Rate - daily                                   3.701426
# Monthly Consumer Confidence Index                            -40.127664
# Monthly Consumer Price Index                                  93.599630
# Number of Employees - quarterly                             5167.595140
# Quarterly Employment Variation rate                            0.163925
#
# Education                                           university.degree  \
# Age of client                                               39.017405
# Contracts performed during Campaign                          2.583070
# Contracts previously performed before this cont...           0.207278
# Days Since Clinet contact                                  947.900316
# Duration in seconds of last conversation                   247.707278
# Euribor 3 Month Rate - daily                                 3.547132
# Monthly Consumer Confidence Index                          -39.830063
# Monthly Consumer Price Index                                93.499109
# Number of Employees - quarterly                           5163.023180
# Quarterly Employment Variation rate                         -0.009731
#
# Education                                               unknown
# Age of client                                         42.826347
# Contracts performed during Campaign                    2.538922
# Contracts previously performed before this cont...     0.263473
# Days Since Clinet contact                            939.700599
# Duration in seconds of last conversation             267.281437
# Euribor 3 Month Rate - daily                           3.410174
# Monthly Consumer Confidence Index                    -39.487425
# Monthly Consumer Price Index                          93.637455
# Number of Employees - quarterly                     5151.260479
# Quarterly Employment Variation rate                   -0.074251

# %% [markdown]
# Using multiple columns in a pivot

# %%
#multiple pivots
df1.pivot_table(columns={'Education', 'Contact', 'Month', 'Housing', 'Day'})
# Out:
#                                  Education  Month  Housing  Contact    Day
# Age of client                    basic.4y   apr    no       cellular   fri      45.0
#                                                                        mon      41.0
#                                                                        thu      45.0
#                                                                        tue      56.5
#                                                             telephone  tue      59.0
#                                                                                ...
# Number of Employees - quarterly  unknown    oct    yes      telephone  tue    5195.8
#                                             sep    no       cellular   thu    5017.5
#                                                    yes      cellular   thu    4963.6
#                                                                        tue    4963.6
#                                                                        wed    4963.6
# Length: 8290, dtype: float64

# %% [markdown]
# ### Replace '999' values with NaN in 'pdays', now 'Days Since Client contact' column

# %%
# the value '999' is giving us an incorrect value while looking at column named 'Days since client contact'
# this will give us accurate numbers when we aggregate them and do further analysis later
df1.replace(999, np.nan)
# we now see NaN in 'Days since client contact' column
# Out:
#       Age of client Employment Status Marital Status          Education  \
# 0                30       blue-collar        married           basic.9y
# 1                39          services         single        high.school
# 2                25          services        married        high.school
# 3                38          services        married           basic.9y
# 4                47            admin.        married  university.degree
# ...             ...               ...            ...                ...
# 4114             30            admin.        married           basic.6y
# 4115             39            admin.        married        high.school
# 4116             27           student         single        high.school
# 4117             58            admin.        married        high.school
# 4118             34        management         single        high.school
#
#      Default  Housing     Loan    Contact Month  Day  ...  \
# 0         no      yes       no   cellular   may  fri  ...
# 1         no       no       no  telephone   may  fri  ...
# 2         no      yes       no  telephone   jun  wed  ...
# 3         no  unknown  unknown  telephone   jun  fri  ...
# 4         no      yes       no   cellular   nov  mon  ...
# ...      ...      ...      ...        ...   ...  ...  ...
# 4114      no      yes      yes   cellular   jul  thu  ...
# 4115      no      yes       no  telephone   jul  fri  ...
# 4116      no       no       no   cellular   may  mon  ...
# 4117      no       no       no   cellular   aug  fri  ...
# 4118      no      yes       no   cellular   nov  wed  ...
#
#       Contracts performed during Campaign  Days Since Clinet contact  \
# 0                                       2                        NaN
# 1                                       4                        NaN
# 2                                       1                        NaN
# 3                                       3                        NaN
# 4                                       1                        NaN
# ...                                   ...                        ...
# 4114                                    1                        NaN
# 4115                                    1                        NaN
# 4116                                    2                        NaN
# 4117                                    1                        NaN
# 4118                                    1                        NaN
#
#       Contracts previously performed before this contract  \
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 4114                                                  0
# 4115                                                  0
# 4116                                                  1
# 4117                                                  0
# 4118                                                  0
#
#       Prev. Marketing Outcome Quarterly Employment Variation rate  \
# 0                 nonexistent                                -1.8
# 1                 nonexistent                                 1.1
# 2                 nonexistent                                 1.4
# 3                 nonexistent                                 1.4
# 4                 nonexistent                                -0.1
# ...                       ...                                 ...
# 4114              nonexistent                                 1.4
# 4115              nonexistent                                 1.4
# 4116                  failure                                -1.8
# 4117              nonexistent                                 1.4
# 4118              nonexistent                                -0.1
#
#       Monthly Consumer Price Index  Monthly Consumer Confidence Index  \
# 0                           92.893                              -46.2
# 1                           93.994                              -36.4
# 2                           94.465                              -41.8
# 3                           94.465                              -41.8
# 4                           93.200                              -42.0
# ...                            ...                                ...
# 4114                        93.918                              -42.7
# 4115                        93.918                              -42.7
# 4116                        92.893                              -46.2
# 4117                        93.444                              -36.1
# 4118                        93.200                              -42.0
#
#       Euribor 3 Month Rate - daily  Number of Employees - quarterly  \
# 0                            1.313                           5099.1
# 1                            4.855                           5191.0
# 2                            4.962                           5228.1
# 3                            4.959                           5228.1
# 4                            4.191                           5195.8
# ...                            ...                              ...
# 4114                         4.958                           5228.1
# 4115                         4.959                           5228.1
# 4116                         1.354                           5099.1
# 4117                         4.966                           5228.1
# 4118                         4.120                           5195.8
#
#       Term Deposit?
# 0                no
# 1                no
# 2                no
# 3                no
# 4                no
# ...             ...
# 4114             no
# 4115             no
# 4116             no
# 4117             no
# 4118             no
#
# [4119 rows x 21 columns]

# %% [markdown]
# Aggregate without skewed '999' values:

# %%
## creating new df2 to be able to kshow new aggregate for mean of column 'Days since client contact'
df2 = df1.replace(999, np.nan)
df2.agg("mean")
#we see it went from a mean of 960.42 previously to an accurate and truely reflective number of the value that is now a mean of 5.86 days. A large diffference that '999' values caused
# Out:
# Age of client                                            40.113620
# Duration in seconds of last conversation                256.607819
# Contracts performed during Campaign                       2.537266
# Days Since Clinet contact                                 5.862500
# Contracts previously performed before this contract       0.190337
# Quarterly Employment Variation rate                       0.084972
# Monthly Consumer Price Index                             93.579704
# Monthly Consumer Confidence Index                       -40.499102
# Euribor 3 Month Rate - daily                              3.621356
# Number of Employees - quarterly                        5166.481695
# dtype: float64

# %% [markdown]
# ## 3 -- Missing Attribute Values:
#
# After running some various analysis and breifly learning this dataset, we were able to identify various "unknown" labels. In most cases, they were labels as 'unknown' or 'nonexistent' that was mentioned and discussed above in the workset. These cases of 'unknown' or 'nonexistent' in particular had numerous interger data in their 'unknown' or 'nonexistent' class with corresponding data - therfore: we will not change or tamper with this data as it could lead to further insight or analysis in the future. Without enough knowledge of the dataset and more information upon what these variables mean, we will conclude that they are valueable and we will not make any change or adjustment to the dataset on that front, other than take notes for now. There was however, 1 column that did require changes to be made. It was the 'pdays' column that was renamed to be 'Days since client contact' for clarification purposes. In that 'Days since client contact' column, there were many '999' values along with other much smaller numbers to represent days since last in contact with client. The 999 value was skewing the final results. To eliminate this skewed aggregation/imputation, we changed the '999' values to be 'NaN' values (non interger) to not skew the data. With this change, we were able to better represent the intigrity of the dataset and provide numbers that are not altered due to 'missing' or 'distorted' data. After there changes and note, we will be able to pass the dataset along for further data analysis if needed.

# %% [markdown]
# ## Conclusion
# In summary, we were able to reference the bank-additional-names.txt file with the bank-additional.csv to make changes by removing unnesecarry abbreviations/spaces/capitalizations to more "meaningful" names to capture the reader and make it easier to understand. We changed column types to match the appropriate feature being analyzed and replaced seperators in strings. We dissected the dataset and decided to leave the 'unknown' and 'nonexistent' data, as they contained useful metrics and intergers for future analysis potentially. We did however make change to the 'pdays' column that was later chaged to 'Days since client contact' by changing all '999' values that were skewing the metrics with 'NaN' to be able to provide accurate and useful data for further evaluation.

# %% [markdown]
# ## References:
# Chen, D. Y. (2019). Python Data Analysis. Pearson Addison Wesley Data & Analytics Series. In Pandas for Everyone.
#
# Docs.Python.org, . (2020). string — Common string operations. In Docs.Python. Retrieved from https://docs.python.org/3/library/string.html#custom-string-formatting.
#
# Tamang, A. (2018, February 3). Unicode, UTF-8, and ASCII encodings made easy. In Medium. Retrieved from https://medium.com/@apiltamang/unicode-utf-8-and-ascii-encodings-made-easy-5bfbe3a1c45a.
#
# Temple.edu, . (n.d.). introduce the world of ASCII and Unicode. In Temple University. Retrieved from https://sites.temple.edu/lizhe/2018/09/16/introduce-the-world-of-ascii-and-unicode/.
